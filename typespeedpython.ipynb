# %%
import time
a="numeral inch hard both above base should four warme an much sound decide your call washass it best"
while (input("Enter 'yes' if you are ready'"))!='yes':
  print("\n")
t0=time.time()
ip=str(input('enter the phrase: %s as fast as possible' %a))
t1=time.time()  
timetaken=t1-t0
accuracy=len(set(ip.split()) & set(a.split()))
wordcount=len(ip)
print("Acurracy is",accuracy)
print("WPM is",wordcount/timetaken)
# Out:
# Enter 'yes' if you are ready'n
#
#
# Enter 'yes' if you are ready'n
#
#
# Enter 'yes' if you are ready'yes
# enter the phrase: numeral inch hard both above base should four warme an much sound decide your call washass it best as fast as possiblenumeral inch hard both above base shoukd four warme an much sound decide your call washass it best as fast as possible
# Acurracy is 17
# WPM is 2.4220138550671697
